# %% [markdown]
# <a href="https://colab.research.google.com/github/davidriveraarbelaez/IA_Explorador/blob/main/AI_Course_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas
#
# 1. Importar Pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {
    'a': np.random.randint(1,100,size=20),
    'b': np.random.randint(1,100,size=20),
    'c': np.random.randint(1,100,size=20)
    }
)

df
# Out:
#      a   b   c
# 0   32  18  37
# 1   44  76  16
# 2   42  91  71
# 3   17  52  51
# 4   59  95  47
# 5    1  60  97
# 6   37  47   8
# 7   81   4  20
# 8   41  57  88
# 9   62  95  86
# 10  96  82  87
# 11  22  62  35
# 12  27  42  90
# 13  41  72  54
# 14  75  51  30
# 15  47  25  50
# 16  81   7   9
# 17  69  37  41
# 18  25  35   6
# 19  86  24  88
