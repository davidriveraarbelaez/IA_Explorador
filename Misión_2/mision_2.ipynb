# %% [markdown]
# ### 1. Introducción al Aprendizaje Automático y Dataset de películas

# %%
# Cargar y explorar el dataset, así como describir las variables relevantes

import pandas as pd

# Cargar el dataset
data = pd.read_csv('../Datasets/movie_metadata_cleaned.csv')

# Mostrar las primeras filas
data.head()

# Descripción general de las variables
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3952 entries, 0 to 3951
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   num_critic_for_reviews   3952 non-null   float64
#  1   duration                 3952 non-null   float64
#  2   director_facebook_likes  3952 non-null   float64
#  3   actor_3_facebook_likes   3952 non-null   float64
#  4   actor_1_facebook_likes   3952 non-null   float64
#  5   gross                    3952 non-null   float64
#  6   num_user_for_reviews     3952 non-null   float64
#  7   budget                   3952 non-null   float64
#  8   title_year               3952 non-null   float64
#  9   actor_2_facebook_likes   3952 non-null   float64
#  10  imdb_score               3952 non-null   float64
#  11  aspect_ratio             3952 non-null   float64
#  12  movie_facebook_likes     3952 non-null   float64
# dtypes: float64(13)
# memory usage: 401.5 KB
# ...

# %%
# Cargar y explorar el dataset, así como describir las variables relevantes

import pandas as pd

# Cargar el dataset
data = pd.read_csv('../Datasets/movie_metadata_cleaned_2.csv')

# Mostrar las primeras filas
data.head()

# Descripción general de las variables
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   num_critic_for_reviews     3998 non-null   float64
#  1   duration                   3998 non-null   float64
#  2   director_facebook_likes    3998 non-null   float64
#  3   actor_3_facebook_likes     3998 non-null   float64
#  4   actor_1_facebook_likes     3998 non-null   float64
#  5   gross                      3998 non-null   float64
#  6   num_user_for_reviews       3998 non-null   float64
#  7   budget                     3998 non-null   float64
#  8   title_year                 3998 non-null   float64
#  9   actor_2_facebook_likes     3998 non-null   float64
#  10  imdb_score                 3998 non-null   float64
#  11  aspect_ratio               3998 non-null   float64
#  12  movie_facebook_likes       3998 non-null   float64
# ...

# %% [markdown]
# ### 2. **Regresión Lineal para la Predicción de Ingresos Brutos**
#    #### 2.1 Selección de variables y análisis preliminar
#    - Identifica las variables independientes más importantes que podrían influir en los ingresos brutos (variable dependiente). Justifica tu elección con análisis de correlación y gráficos de dispersión.

# %%
# Selección de variables y análisis preliminar

import seaborn as sns
import matplotlib.pyplot as plt

# Correlación con 'gross'
correlation_matrix = data.corr()
gross_correlation = correlation_matrix['gross'].sort_values(ascending=False)
print(gross_correlation)
# Out:
# gross                        1.000000
# num_voted_users              0.629723
# num_user_for_reviews         0.554341
# num_critic_for_reviews       0.467210
# movie_facebook_likes         0.361870
# actor_3_facebook_likes       0.287553
# actor_2_facebook_likes       0.251053
# duration                     0.245321
# cast_total_facebook_likes    0.236081
# imdb_score                   0.199684
# actor_1_facebook_likes       0.149761
# director_facebook_likes      0.143403
# budget                       0.104417
# aspect_ratio                 0.069534
# title_year                   0.036445
# facenumber_in_poster        -0.031322
# Name: gross, dtype: float64
